# %%
# Import dependencies
import pandas as pd

# %%
files2018 = {'Resources/201801.csv','Resources/201802.csv','Resources/201803.csv',
            'Resources/201804.csv','Resources/201805.csv','Resources/201806.csv',
            'Resources/201807.csv','Resources/201808.csv','Resources/201809.csv'}

# Empty lsit
df2018_list =[]

# Loop for each file in the created list
for file in files2018:
    df2018 = pd.read_csv(file)
    df2018_list.append(df2018)

# Concatenate dataframes
df2018 = pd.concat(df2018_list)

df2018
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 569  2018-06-01 01:57:20.5140  2018-06-01 02:06:50.0880
# 1                 480  2018-06-01 02:02:42.3980  2018-06-01 02:10:43.3540
# 2                 692  2018-06-01 02:04:23.6240  2018-06-01 02:15:55.7470
# 3                 664  2018-06-01 03:00:55.4610  2018-06-01 03:11:59.9060
# 4                 818  2018-06-01 06:04:54.4270  2018-06-01 06:18:32.6170
# ...               ...                       ...                       ...
# 1977172           592  2018-08-31 23:59:27.6530  2018-09-01 00:09:20.5800
# 1977173           451  2018-08-31 23:59:42.8400  2018-09-01 00:07:14.5330
# 1977174           472  2018-08-31 23:59:48.5310  2018-09-01 00:07:41.0410
# 1977175          1239  2018-08-31 23:59:50.7620  2018-09-01 00:20:30.4570
# 1977176           738  2018-08-31 23:59:55.7330  2018-09-01 00:12:14.0300
#
#          start station id        start station name  start station latitude  \
# ...

# %%
# Gender mapping
gendertext = {0:"Unknown", 1:"Male", 2:"Female"}

df2018['gender'] = df2018['gender'].map(gendertext)

df2018
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 569  2018-06-01 01:57:20.5140  2018-06-01 02:06:50.0880
# 1                 480  2018-06-01 02:02:42.3980  2018-06-01 02:10:43.3540
# 2                 692  2018-06-01 02:04:23.6240  2018-06-01 02:15:55.7470
# 3                 664  2018-06-01 03:00:55.4610  2018-06-01 03:11:59.9060
# 4                 818  2018-06-01 06:04:54.4270  2018-06-01 06:18:32.6170
# ...               ...                       ...                       ...
# 1977172           592  2018-08-31 23:59:27.6530  2018-09-01 00:09:20.5800
# 1977173           451  2018-08-31 23:59:42.8400  2018-09-01 00:07:14.5330
# 1977174           472  2018-08-31 23:59:48.5310  2018-09-01 00:07:41.0410
# 1977175          1239  2018-08-31 23:59:50.7620  2018-09-01 00:20:30.4570
# 1977176           738  2018-08-31 23:59:55.7330  2018-09-01 00:12:14.0300
#
#          start station id        start station name  start station latitude  \
# ...

# %%
df2018.to_csv('Resources/citibike2018.csv', index = False)
